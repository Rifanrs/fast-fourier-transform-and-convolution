# %%
import numpy as np
import matplotlib.pyplot as plt
import csv

# Baca data dari file CSV
data = []
with open('C:/Users/Lenovo/JUPYTER LAB/data sukabumi.csv', 'r') as file:
    csv_reader = csv.reader(file)
    for row in csv_reader:
        data.append(float(row[0]))  # Sesuaikan dengan kolom data yang akan diolah

# Konversi data menjadi array NumPy
data_array = np.array(data)

# Melakukan FFT
fft_result = np.fft.fft(data_array)
N = len(data_array)  # Jumlah data

# Menghitung frekuensi
Fs = 1.0  # Frekuensi sampel
frequencies = np.fft.fftfreq(N, 1/Fs)
positive_frequencies = frequencies[:N//2]
magnitude = np.abs(fft_result[:N//2])

# Plot spektrum frekuensi
plt.plot(positive_frequencies, magnitude)
plt.xlabel('Frekuensi (Hz)')
plt.ylabel('Magnitude')
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 10
#       8     csv_reader = csv.reader(file)
#       9     for row in csv_reader:
# ---> 10         data.append(float(row[0]))  # Sesuaikan dengan kolom data yang akan diolah
#      12 # Konversi data menjadi array NumPy
#      13 data_array = np.array(data)
#
# ValueError: could not convert string to float: '# dataset: GeoCSV 2.0'

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv

# Baca data dari file CSV
data = []
with open('C:/Users/Lenovo/JUPYTER LAB/data sukabumi.csv', 'r') as file:
    csv_reader = csv.reader(file)
    
    # Iterasi melalui baris dalam file CSV
    for row in csv_reader:
        if len(row) > 0 and row[0].replace('.', '', 1).isdigit():
            data.append(float(row[0]))  # Sesuaikan dengan kolom data yang akan diolah

# Konversi data menjadi array NumPy
data_array = np.array(data)

# Melakukan FFT
fft_result = np.fft.fft(data_array)
N = len(data_array)  # Jumlah data

# Menghitung frekuensi
Fs = 1.0  # Frekuensi sampel
frequencies = np.fft.fftfreq(N, 1/Fs)
positive_frequencies = frequencies[:N//2]
magnitude = np.abs(fft_result[:N//2])

# Plot spektrum frekuensi
plt.plot(positive_frequencies, magnitude)
plt.xlabel('Frekuensi (Hz)')
plt.ylabel('Magnitude')
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv

# Baca data dari file CSV
data = []
header_info = {}  # Untuk menyimpan informasi header
with open('C:/Users/Lenovo/JUPYTER LAB/data sukabumi.csv', 'r') as file:
    csv_reader = csv.reader(file)
    
    # Baca informasi header
    for row in csv_reader:
        if len(row) > 0 and row[0].startswith('# '):
            key, value = row[0].split(': ')
            header_info[key[2:]] = value  # Menghilangkan tanda "#" dan menyimpan info header
        else:
            break  # Hentikan setelah membaca header

    # Baca data numerik
    for row in csv_reader:
        if len(row) > 0 and row[0].replace('.', '', 1).isdigit():
            data.append(float(row[0]))

# Konversi data menjadi array NumPy
data_array = np.array(data)

# Melakukan FFT
fft_result = np.fft.fft(data_array)
N = len(data_array)  # Jumlah data

# Menghitung frekuensi
Fs = 1.0  # Frekuensi sampel
frequencies = np.fft.fftfreq(N, 1/Fs)
positive_frequencies = frequencies[:N//2]
magnitude = np.abs(fft_result[:N//2])

# Plot spektrum frekuensi
plt.plot(positive_frequencies, magnitude)
plt.xlabel('Frekuensi (Hz)')
plt.ylabel('Magnitude')
plt.grid()

# Menambahkan informasi header ke judul
info_str = "\n".join([f"{key}: {value}" for key, value in header_info.items()])
plt.title(f"Spektrum Frekuensi\n{info_str}")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv

# Membaca data dari file CSV (dengan melewati baris pertama/header)
data = []
with open('C:/Users/Lenovo/JUPYTER LAB/Siul 10 ms.csv', 'r') as file:
    csv_reader = csv.reader(file, delimiter=';')
    next(csv_reader)  # Melewati baris pertama (header)
    for row in csv_reader:
        # Ganti tanda koma (,) dengan tanda titik (.) pada data waktu dan rekaman
        # lalu konversi ke float
        time = float(row[0].replace(',', '.'))
        recording = float(row[1].replace(',', '.'))
        data.append([time, recording])

# Memisahkan waktu dan rekaman
time_data = [row[0] for row in data]  # Kolom waktu (ms)
recording_data = [row[1] for row in data]  # Kolom recording (a.u)

# Melakukan FFT pada rekaman
fft_result = np.fft.fft(recording_data)
N = len(recording_data)  # Jumlah data

# Menghitung frekuensi
Fs = 1.0 / (time_data[1] - time_data[0])  # Frekuensi sampel (diasumsikan interval waktu konstan)
frequencies = np.fft.fftfreq(N, 1/Fs)
positive_frequencies = frequencies[:N//2]
magnitude = np.abs(fft_result[:N//2])

# Plot spektrum frekuensi
plt.plot(positive_frequencies, magnitude)
plt.xlabel('Frekuensi (Hz)')
plt.ylabel('Magnitude')
plt.grid()

# Menambahkan informasi waktu ke judul
time_info = f"Time: {time_data[0]} - {time_data[-1]} ms"
plt.title(f"Spektrum Frekuensi\n{time_info}")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import csv

# Membaca data dari file CSV (dengan melewati baris pertama/header)
data = []
with open('C:/Users/Lenovo/JUPYTER LAB/Siul 10 ms.csv', 'r') as file:
    csv_reader = csv.reader(file, delimiter=';')
    next(csv_reader)  # Melewati baris pertama (header)
    for row in csv_reader:
        # Ganti tanda koma (,) dengan tanda titik (.) pada data waktu dan rekaman
        # lalu konversi ke float
        time = float(row[0].replace(',', '.'))
        recording = float(row[1].replace(',', '.'))
        data.append([time, recording])

# Memisahkan waktu dan rekaman
time_data = [row[0] for row in data]  # Kolom waktu (ms)
recording_data = [row[1] for row in data]  # Kolom recording (a.u)

# Melakukan FFT pada rekaman
fft_result = np.fft.fft(recording_data)
N = len(recording_data)  # Jumlah data

# Menghitung frekuensi
Fs = 1.0 / (time_data[1] - time_data[0])  # Frekuensi sampel (diasumsikan interval waktu konstan)
frequencies = np.fft.fftfreq(N, 1/Fs)
positive_frequencies = frequencies[:N//2]
magnitude = np.abs(fft_result[:N//2])

# Plot spektrum frekuensi
plt.plot(positive_frequencies, magnitude)
plt.xlabel('Frekuensi (Hz)')
plt.ylabel('Magnitude')
plt.grid()

# Menambahkan informasi waktu ke judul
time_info = f"Time: {time_data[0]} - {time_data[-1]} ms"
plt.title(f"Spektrum Frekuensi\n{time_info}")

plt.show()
